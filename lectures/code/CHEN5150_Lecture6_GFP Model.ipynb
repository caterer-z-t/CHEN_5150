# %%
from lectures.code.Lecture6_chromophore import chromophore
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %%
t = np.linspace(0 ,1200, 500)
y0 = np.zeros(4)
y = odeint(chromophore, y0, t, tfirst=True)

plt.figure()
plt.plot(t, y[:, 3])
plt.xlabel("Time [min]")
plt.ylabel("GFP Concentration [AU]")
# Out:
# Text(0, 0.5, 'GFP Concentration [AU]')
